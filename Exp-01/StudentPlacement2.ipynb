# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns
print("Library Versions")
print("-" * 40)
print(f"Pandas         : {pd.__version__}")
print(f"NumPy          : {np.__version__}")
print(f"Scikit-learn   : {sklearn.__version__}")
print(f"Matplotlib     : {matplotlib.__version__}")
print(f"Seaborn        : {sns.__version__}")
# Out:
# Library Versions
# ----------------------------------------
# Pandas         : 2.2.2
# NumPy          : 2.0.2
# Scikit-learn   : 1.6.1
# Matplotlib     : 3.10.0
# Seaborn        : 0.13.2

# %%
import pandas as pd
import seaborn as sns

# %%
from pandas import read_csv
df=read_csv('/content/student_placement_synthetic.csv')

# %%
df.head(5)
# Out:
#      branch college_tier  cgpa  backlogs  coding_skills  dsa_score  \
# 0       ECE       Tier-3  6.70         0            7.6        4.4
# 1  Chemical       Tier-2  5.70         0            5.4        7.9
# 2        EE       Tier-2  7.19         0            5.6        6.8
# 3        CE       Tier-2  6.48         0            5.2        3.1
# 4       CSE       Tier-2  6.71         1            5.9        4.7
#
#    aptitude_score  communication_skills  ml_knowledge  system_design  \
# 0            49.5                   3.7           6.4            0.3
# 1            72.0                   8.3           6.3            1.9
# 2            79.1                   7.4           4.4            5.2
# 3            48.4                   5.0           1.1            6.7
# 4            61.2                   4.3           2.7            2.8
#
#    internships  projects_count  certifications  hackathons  \
# 0            1               4               4           3
# ...

# %%
df.tail(5)
# Out:
#       branch college_tier  cgpa  backlogs  coding_skills  dsa_score  \
# 99995     IT       Tier-3  6.08         0            3.1        5.4
# 99996     IT       Tier-3  7.46         0            4.8        6.8
# 99997     EE       Tier-2  7.94         0            4.9        9.1
# 99998     ME       Tier-3  6.63         0            5.0        8.0
# 99999    ECE       Tier-1  7.00         0            2.8        5.3
#
#        aptitude_score  communication_skills  ml_knowledge  system_design  \
# 99995            67.4                   4.3           9.1            3.8
# 99996            59.5                   7.6           5.6            2.4
# 99997            55.1                   6.1           3.5            5.2
# 99998            65.0                   5.7           6.2            0.2
# 99999            64.5                   5.7           5.7            3.4
#
#        internships  projects_count  certifications  hackathons  \
# ...

# %%
df.shape
# Out:
# (100000, 18)

# %%
rows, columns=df.shape
rows
# Out:
# 100000

# %%
df.columns
# Out:
# Index(['branch', 'college_tier', 'cgpa', 'backlogs', 'coding_skills',
#        'dsa_score', 'aptitude_score', 'communication_skills', 'ml_knowledge',
#        'system_design', 'internships', 'projects_count', 'certifications',
#        'hackathons', 'open_source_contributions', 'extracurriculars',
#        'placement_status', 'salary_package_lpa'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of          branch college_tier  cgpa  backlogs  coding_skills  dsa_score  \
# 0           ECE       Tier-3  6.70         0            7.6        4.4
# 1      Chemical       Tier-2  5.70         0            5.4        7.9
# 2            EE       Tier-2  7.19         0            5.6        6.8
# 3            CE       Tier-2  6.48         0            5.2        3.1
# 4           CSE       Tier-2  6.71         1            5.9        4.7
# ...         ...          ...   ...       ...            ...        ...
# 99995        IT       Tier-3  6.08         0            3.1        5.4
# 99996        IT       Tier-3  7.46         0            4.8        6.8
# 99997        EE       Tier-2  7.94         0            4.9        9.1
# 99998        ME       Tier-3  6.63         0            5.0        8.0
# 99999       ECE       Tier-1  7.00         0            2.8        5.3
#
#        aptitude_score  communication_skills  ml_knowledge  system_design  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# branch                           0
# college_tier                     0
# cgpa                             0
# backlogs                         0
# coding_skills                    0
# dsa_score                        0
# aptitude_score                   0
# communication_skills             0
# ml_knowledge                     0
# system_design                    0
# internships                      0
# projects_count                   0
# certifications                   0
# hackathons                       0
# open_source_contributions        0
# extracurriculars                 0
# placement_status                 0
# salary_package_lpa           31525
# dtype: int64

# %%
df_clean = df.copy()

print(" DATA CLEANING PIPELINE")

print(f"\nStarting shape: {df_clean.shape}")
print(f"Starting missing: {df_clean.isnull().sum().sum()}")
# Out:
#  DATA CLEANING PIPELINE
#
# Starting shape: (100000, 18)
# Starting missing: 31525

# %%
print("\nHandling Missing Salary Values")
print("-" * 50)

not_placed = df_clean[df_clean['placement_status'] == 0]
placed = df_clean[df_clean['placement_status'] == 1]

print(f"   Students not placed: {len(not_placed):,}")
print(f"   Students placed: {len(placed):,}")
print(f"   Missing salary values: {df_clean['salary_package_lpa'].isnull().sum():,}")
print(f"   ✓ Missing salaries match non-placement count: {df_clean['salary_package_lpa'].isnull().sum() == len(not_placed)}")
# Out:
# Handling Missing Salary Values
# --------------------------------------------------
#    Students not placed: 31,525
#    Students placed: 68,475
#    Missing salary values: 31,525
#    ✓ Missing salaries match non-placement count: True

# %%
print("\nHandling Missing Salary Values")
print("-" * 50)

not_placed = df_clean[df_clean['placement_status'] == 0]
placed = df_clean[df_clean['placement_status'] == 1]

print(f"   Students not placed: {len(not_placed):,}")
print(f"   Students placed: {len(placed):,}")
print(f"   Missing salary values: {df_clean['salary_package_lpa'].isnull().sum():,}")
print(f"   ✓ Missing salaries match non-placement count: {df_clean['salary_package_lpa'].isnull().sum() == len(not_placed)}")
# Out:
# Handling Missing Salary Values
# --------------------------------------------------
#    Students not placed: 31,525
#    Students placed: 68,475
#    Missing salary values: 31,525
#    ✓ Missing salaries match non-placement count: True

# %%
print("\nVerifying Data Types")
print("-" * 50)
categorical_cols = ['branch', 'college_tier']
for col in categorical_cols:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].astype('category')
        print(f"    Set {col} as categorical")
df_clean['placement_status'] = df_clean['placement_status'].astype(int)
print(f"   Set placement_status as integer")

print(f"\nFinal shape: {df_clean.shape}")
print(f"Data retained: {100*len(df_clean)/len(df):.1f}%")

print(" CLEANING COMPLETE....")
# Out:
# Verifying Data Types
# --------------------------------------------------
#     Set branch as categorical
#     Set college_tier as categorical
#    Set placement_status as integer
#
# Final shape: (100000, 18)
# Data retained: 100.0%
#  CLEANING COMPLETE....
